# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Airline_df = pd.read_csv("airline_routes.csv")

# %%
Airline_df
# Out:
#            airline_name                dpt_airport_name         dpt_city  \
# 0             airline_a                       airport_a           city_a
# 1             airline_a                       airport_a           city_a
# 2             airline_a                       airport_a           city_a
# 3             airline_b                       airport_a           city_a
# 4            Aerocondor                           Sochi            Sochi
# 5            Aerocondor                       Astrakhan        Astrakhan
# 6            Aerocondor                       Astrakhan        Astrakhan
# 7            Aerocondor                       Balandino      Chelyabinsk
# 8            Aerocondor                       Balandino      Chelyabinsk
# 9            Aerocondor                      Domododevo           Moscow
# 10           Aerocondor                      Domododevo           Moscow
# 11           Aerocondor                      Domododevo           Moscow
# ...

# %%
#key=airline
#value=list[name of plane model]

# %%
Airline_df[4:]
# Out:
#            airline_name                dpt_airport_name         dpt_city  \
# 4            Aerocondor                           Sochi            Sochi
# 5            Aerocondor                       Astrakhan        Astrakhan
# 6            Aerocondor                       Astrakhan        Astrakhan
# 7            Aerocondor                       Balandino      Chelyabinsk
# 8            Aerocondor                       Balandino      Chelyabinsk
# 9            Aerocondor                      Domododevo           Moscow
# 10           Aerocondor                      Domododevo           Moscow
# 11           Aerocondor                      Domododevo           Moscow
# 12           Aerocondor  Belgorod International Airport         Belgorod
# 13           Aerocondor  Belgorod International Airport         Belgorod
# 14           Aerocondor                   Heydar Aliyev             Baku
# 15           Aerocondor                       Khrabrovo      Kaliningrad
# ...

# %%
Airline_name=Airline_df.values

# %%
Airline_name
# Out:
# array([['airline_a', 'airport_a', 'city_a', ..., 'country_b',
#         'manifac_a', 'plane_a'],
#        ['airline_a', 'airport_a', 'city_a', ..., 'country_b',
#         'manifac_a', 'plane_b'],
#        ['airline_a', 'airport_a', 'city_a', ..., 'country_b',
#         'manifac_a', 'plane_c'],
#        ...,
#        ['Apache Air', 'Manas', 'Bishkek', ..., 'Russia', 'Boeing',
#         '737-400'],
#        ['Apache Air', 'Manas', 'Bishkek', ..., 'Kyrgyzstan', 'Boeing',
#         '737-400'],
#        ['Apache Air', 'Osh', 'Osh', ..., 'Kyrgyzstan', 'Boeing',
#         '737-400']], dtype=object)

# %%
Data_used = Airline_df[4:]

# %%
#Data_used[(Data_used["header_name"]=="yourcondition")&("Data_used["header_name"]=="yourcondition")]

# %%
#value output = pyarray
#tolist output = lists of list

# %%
departure_country
de
arrival

# %%
Data_used[(Data_used["dpt_country"]=="Singapore")&(Data_used["dpt_city"]=="Singapore")&(Data_used["arr_country"]=="Hong Kong")&(Data_used["arr_city"]=="Hong Kong")]
# Out:
#                airline_name dpt_airport_name   dpt_city dpt_country  \
# 362    Jetstar Asia Airways      Changi Intl  Singapore   Singapore
# 14165     Air India Limited      Changi Intl  Singapore   Singapore
# 24636        Cathay Pacific      Changi Intl  Singapore   Singapore
# 24637        Cathay Pacific      Changi Intl  Singapore   Singapore
# 24638        Cathay Pacific      Changi Intl  Singapore   Singapore
# 24639        Cathay Pacific      Changi Intl  Singapore   Singapore
# 67486    Singapore Airlines      Changi Intl  Singapore   Singapore
# 67487    Singapore Airlines      Changi Intl  Singapore   Singapore
# 67488    Singapore Airlines      Changi Intl  Singapore   Singapore
# 72264         Tiger Airways      Changi Intl  Singapore   Singapore
# 72861                 Scoot      Changi Intl  Singapore   Singapore
# 78466       United Airlines      Changi Intl  Singapore   Singapore
# 82546            US Airways      Changi Intl  Singapore   Singapore
#
# ...

# %%
filter_data=Data_used[(Data_used["dpt_country"]=="Singapore")&(Data_used["dpt_city"]=="Singapore")&(Data_used["arr_country"]=="Hong Kong")&(Data_used["arr_city"]=="Hong Kong")].values.tolist()

# %%
filter_data
# Out:
# [['Jetstar Asia Airways',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Airbus',
#   'A320-100/200'],
#  ['Air India Limited',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Boeing',
#   '777-300ER'],
#  ['Cathay Pacific',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Airbus',
#   'A330-300'],
#  ['Cathay Pacific',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Boeing',
#   '777-200'],
#  ['Cathay Pacific',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Boeing',
#   '777-300'],
#  ['Cathay Pacific',
#   'Changi Intl',
#   'Singapore',
#   'Singapore',
#   'Hong Kong Intl',
#   'Hong Kong',
#   'Hong Kong',
#   'Boeing',
#   '777-300ER'],
# ...

# %%
#.append()

# %%
#for x in filter_data:

# %%
#The output should then give a dictionary with:
1. Names of the airlines as KEYS
2. VALUES will be the list of aircraft model/type

# %%
airline_name_df = airline_name

# %%
#grab {airline_name : aircraft_model}

# %%
#airline_aircraft = {airline_name : aircraft_model}

# %%
for x in filter_data:
    print(x)
# Out:
# ['Jetstar Asia Airways', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Airbus', 'A320-100/200']
# ['Air India Limited', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Boeing', '777-300ER']
# ['Cathay Pacific', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Airbus', 'A330-300']
# ['Cathay Pacific', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Boeing', '777-200']
# ['Cathay Pacific', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Boeing', '777-300']
# ['Cathay Pacific', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Boeing', '777-300ER']
# ['Singapore Airlines', 'Changi Intl', 'Singapore', 'Singapore', 'Hong Kong Intl', 'Hong Kong', 'Hong Kong', 'Boeing', '777-200']
# ...

# %%
airline_aircraft = {}
for x in filter_data:
    if x[0] in airline_aircraft:
         airline_aircraft[x[0]].append(x[8])
    else:
        airline_aircraft[x[0]]=[x[8]]
print(airline_aircraft)
    
    
    
    
    #airline_aircraft = []
    #airline_aircraft.append()
# Out:
# {'Jetstar Asia Airways': ['A320-100/200'], 'Air India Limited': ['777-300ER'], 'Cathay Pacific': ['A330-300', '777-200', '777-300', '777-300ER'], 'Singapore Airlines': ['777-200', 'A380-800', '777-300ER'], 'Tiger Airways': ['A320-100/200'], 'Scoot': ['777-200'], 'United Airlines': ['777'], 'US Airways': ['777-300ER']}

# %%
airline_aircraft
# Out:
# {'Jetstar Asia Airways': ['A320-100/200'],
#  'Air India Limited': ['777-300ER'],
#  'Cathay Pacific': ['A330-300', '777-200', '777-300', '777-300ER'],
#  'Singapore Airlines': ['777-200', 'A380-800', '777-300ER'],
#  'Tiger Airways': ['A320-100/200'],
#  'Scoot': ['777-200'],
#  'United Airlines': ['777'],
#  'US Airways': ['777-300ER']}

# %%
def routes_info(d_city,d_country,arr_city,darrcountry):
